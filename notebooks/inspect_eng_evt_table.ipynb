# %%
$ENDPOINT='http://ddb-local:8000'
aws dynamodb list-tables --no-cli-pager --endpoint-url $ENDPOINT
# Out:
# {
#     "TableNames": [
#         "EngagementEventsTable",
#         "MysfitsTable"
#     ]
# }

# %%
aws dynamodb describe-table --table-name EngagementEventsTable --endpoint-url $ENDPOINT
# Out:
# {
#     "Table": {
#         "AttributeDefinitions": [
#             {
#                 "AttributeName": "EngagementEventId",
#                 "AttributeType": "S"
#             },
#             {
#                 "AttributeName": "EngagementVersion",
#                 "AttributeType": "S"
#             }
#         ],
#         "TableName": "EngagementEventsTable",
#         "KeySchema": [
#             {
#                 "AttributeName": "EngagementEventId",
#                 "KeyType": "HASH"
#             },
#             {
#                 "AttributeName": "EngagementVersion",
#                 "KeyType": "RANGE"
#             }
#         ],
#         "TableStatus": "ACTIVE",
#         "CreationDateTime": "2020-11-14T23:16:44.939000+00:00",
#         "ProvisionedThroughput": {
#             "LastIncreaseDateTime": "1970-01-01T00:00:00+00:00",
#             "LastDecreaseDateTime": "1970-01-01T00:00:00+00:00",
#             "NumberOfDecreasesToday": 0,
#             "ReadCapacityUnits": 5,
#             "WriteCapacityUnits": 5
#         },
#         "TableSizeBytes": 906,
#         "ItemCount": 4,
#         "TableArn": "arn:aws:dynamodb:ddblocal:000000000000:table/EngagementEventsTable"
#     }
# }

# %%
aws dynamodb scan --table-name EngagementEventsTable --endpoint-url $ENDPOINT
# Out:
# {
#     "Items": [
#         {
#             "Event": {
#                 "M": {
#                     "TeamsName": {
#                         "S": "flytrap and co"
#                     },
#                     "ActionVersion": {
#                         "S": "1"
#                     },
#                     "Action": {
#                         "S": "Created"
#                     },
#                     "Owner": {
#                         "S": "Fun Guy"
#                     },
#                     "SfdcId": {
#                         "S": "PROJ-1234"
#                     },
#                     "ProjectName": {
#                         "S": "A major project"
#                     },
#                     "Region": {
#                         "S": "NARNIA"
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "BS.Domain.DAL.EventEnvelopeDal+envelope@75"
#             },
#             "EngagementVersion": {
#                 "S": "1"
#             },
#             "TimeStamp": {
#                 "S": "11/16/2020 00:45:08"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "TeamsName": {
#                         "S": "flytrap"
#                     },
#                     "Region": {
#                         "S": "Narnia"
#                     },
#                     "SFDCID": {
#                         "S": "Project-1234"
#                     },
#                     "Action": {
#                         "S": "Create"
#                     },
#                     "Owner": {
#                         "S": "givepac"
#                     },
#                     "ProjectName": {
#                         "S": "Super fancy infrastructure engagement"
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "1"
#             },
#             "TimeStamp": {
#                 "S": "Now"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "Action": {
#                         "S": "Update"
#                     },
#                     "Payload": {
#                         "M": {
#                             "TeamsName": {
#                                 "S": "flytrap"
#                             },
#                             "Region": {
#                                 "S": "Narnia"
#                             },
#                             "SFDCID": {
#                                 "S": "Project-1234"
#                             },
#                             "Owner": {
#                                 "S": "givepac"
#                             },
#                             "ProjectName": {
#                                 "S": "Super fancy infrastructure engagement"
#                             }
#                         }
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "2"
#             },
#             "TimeStamp": {
#                 "S": "Now+1"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "Action": {
#                         "S": "Create"
#                     },
#                     "Payload": {
#                         "M": {
#                             "TeamsName": {
#                                 "S": "flytrap"
#                             },
#                             "Region": {
#                                 "S": "Narnia"
#                             },
#                             "SFDCID": {
#                                 "S": "Project-1234"
#                             },
#                             "Owner": {
#                                 "S": "givepac"
#                             },
#                             "ProjectName": {
#                                 "S": "Super fancy infrastructure engagement"
#                             }
#                         }
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "3"
#             },
#             "TimeStamp": {
#                 "S": "Now+2"
#             }
#         }
#     ],
#     "Count": 4,
#     "ScannedCount": 4,
#     "ConsumedCapacity": null
# }
