# %%
$ENDPOINT='http://ddb-local:8000'
aws dynamodb list-tables --no-cli-pager --endpoint-url $ENDPOINT
# Out:
# <div>
#     <div id='dotnet-interactive-this-cell-10774.a921411eefbf45b9a0878c426c429fb7' style='display: none'>
#         The below script needs to be able to find the current output cell; this is an easy method to get it.
#     </div>
#     <script type='text/javascript'>
# // ensure `require` is available globally
# if (typeof require !== typeof Function || typeof require.config !== typeof Function) {
#     let require_script = document.createElement('script');
#     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
#     require_script.setAttribute('type', 'text/javascript');
#     require_script.onload = function () {
#         loadDotnetInteractiveApi();
#     };
#
#     document.getElementsByTagName('head')[0].appendChild(require_script);
# }
# else {
#     loadDotnetInteractiveApi();
# }
#
# async function probeAddresses(probingAddresses) {
#     function timeout(ms, promise) {
#         return new Promise(function (resolve, reject) {
#             setTimeout(function () {
#                 reject(new Error('timeout'))
#             }, ms)
#             promise.then(resolve, reject)
#         })
#     }
#
#     if (Array.isArray(probingAddresses)) {
#         for (let i = 0; i < probingAddresses.length; i++) {
#
#             let rootUrl = probingAddresses[i];
#
#             if (!rootUrl.endsWith('/')) {
#                 rootUrl = `${rootUrl}/`;
#             }
#
#             try {
#                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
#                     method: 'POST',
#                     cache: 'no-cache',
#                     mode: 'cors',
#                     timeout: 1000,
#                     headers: {
#                         'Content-Type': 'text/plain'
#                     },
#                     body: probingAddresses[i]
#                 }));
#
#                 if (response.status == 200) {
#                     return rootUrl;
#                 }
#             }
#             catch (e) { }
#         }
#     }
# }
#
# function loadDotnetInteractiveApi() {
#     probeAddresses(["http://172.18.0.5:1024/", "http://127.0.0.1:1024/"])
#         .then((root) => {
#             // use probing to find host url and api resources
#             // load interactive helpers and language services
#             let dotnet_require = require.config({
#                 context: '10774.a921411eefbf45b9a0878c426c429fb7',
#                 paths: {
#                     'dotnet-interactive': `${root}resources`
#                 }
#             }) || require;
#             if (!window.dotnet_require) {
#                 window.dotnet_require = dotnet_require;
#             }
#
#             dotnet_require([
#                     'dotnet-interactive/dotnet-interactive'
#                 ],
#                 function (dotnet) {
#                     dotnet.init(window);
#                 },
#                 function (error) {
#                     console.log(error);
#                 }
#             );
#         })
#         .catch(error => {console.log(error);});
#     }
#     </script>
# </div>
# {
#     "TableNames": [
#         "EngagementEventsTable"
#     ]
# }

# %%
aws dynamodb describe-table --table-name EngagementEventsTable --endpoint-url $ENDPOINT
# Out:
# {
#     "Table": {
#         "AttributeDefinitions": [
#             {
#                 "AttributeName": "EngagementEventId",
#                 "AttributeType": "S"
#             },
#             {
#                 "AttributeName": "EngagementVersion",
#                 "AttributeType": "S"
#             }
#         ],
#         "TableName": "EngagementEventsTable",
#         "KeySchema": [
#             {
#                 "AttributeName": "EngagementEventId",
#                 "KeyType": "HASH"
#             },
#             {
#                 "AttributeName": "EngagementVersion",
#                 "KeyType": "RANGE"
#             }
#         ],
#         "TableStatus": "ACTIVE",
#         "CreationDateTime": "2020-11-20T14:06:27.923000+00:00",
#         "ProvisionedThroughput": {
#             "LastIncreaseDateTime": "1970-01-01T00:00:00+00:00",
#             "LastDecreaseDateTime": "1970-01-01T00:00:00+00:00",
#             "NumberOfDecreasesToday": 0,
#             "ReadCapacityUnits": 5,
#             "WriteCapacityUnits": 5
#         },
#         "TableSizeBytes": 1129,
#         "ItemCount": 5,
#         "TableArn": "arn:aws:dynamodb:ddblocal:000000000000:table/EngagementEventsTable"
#     }
# }

# %%
aws dynamodb scan --table-name EngagementEventsTable --endpoint-url $ENDPOINT
# Out:
# {
#     "Items": [
#         {
#             "Event": {
#                 "M": {
#                     "TeamsName": {
#                         "S": "flytrap"
#                     },
#                     "Region": {
#                         "S": "Narnia"
#                     },
#                     "SFDCID": {
#                         "S": "Project-1234"
#                     },
#                     "Action": {
#                         "S": "Create"
#                     },
#                     "Owner": {
#                         "S": "givepac"
#                     },
#                     "ProjectName": {
#                         "S": "Super fancy infrastructure engagement"
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "1"
#             },
#             "TimeStamp": {
#                 "S": "Now"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "Action": {
#                         "S": "Update"
#                     },
#                     "Payload": {
#                         "M": {
#                             "TeamsName": {
#                                 "S": "flytrap"
#                             },
#                             "Region": {
#                                 "S": "Narnia"
#                             },
#                             "SFDCID": {
#                                 "S": "Project-1234"
#                             },
#                             "Owner": {
#                                 "S": "givepac"
#                             },
#                             "ProjectName": {
#                                 "S": "Super fancy infrastructure engagement"
#                             }
#                         }
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "2"
#             },
#             "TimeStamp": {
#                 "S": "Now+1"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "Action": {
#                         "S": "Create"
#                     },
#                     "Payload": {
#                         "M": {
#                             "TeamsName": {
#                                 "S": "flytrap"
#                             },
#                             "Region": {
#                                 "S": "Narnia"
#                             },
#                             "SFDCID": {
#                                 "S": "Project-1234"
#                             },
#                             "Owner": {
#                                 "S": "givepac"
#                             },
#                             "ProjectName": {
#                                 "S": "Super fancy infrastructure engagement"
#                             }
#                         }
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "4e53920c-505a-4a90-a694-b9300791f0ae"
#             },
#             "EngagementVersion": {
#                 "S": "3"
#             },
#             "TimeStamp": {
#                 "S": "Now+2"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "TeamsName": {
#                         "S": "flytrap and co"
#                     },
#                     "ActionVersion": {
#                         "S": "1"
#                     },
#                     "Owner": {
#                         "S": "Fun Guy"
#                     },
#                     "Action": {
#                         "S": "Created"
#                     },
#                     "SfdcId": {
#                         "S": "PROJ-1234"
#                     },
#                     "ProjectName": {
#                         "S": "A major project"
#                     },
#                     "Region": {
#                         "S": "NARNIA"
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "fd58911c-8285-467e-aaeb-9f27f76d84c4"
#             },
#             "EngagementVersion": {
#                 "S": "1"
#             },
#             "TimeStamp": {
#                 "S": "11/20/2020 14:16:05"
#             }
#         },
#         {
#             "Event": {
#                 "M": {
#                     "TeamsName": {
#                         "S": "flytrap and co"
#                     },
#                     "ActionVersion": {
#                         "S": "1"
#                     },
#                     "Owner": {
#                         "S": "Fun Guy"
#                     },
#                     "Action": {
#                         "S": "Created"
#                     },
#                     "SfdcId": {
#                         "S": "PROJ-1234"
#                     },
#                     "ProjectName": {
#                         "S": "A major project"
#                     },
#                     "Region": {
#                         "S": "NARNIA"
#                     }
#                 }
#             },
#             "EngagementEventId": {
#                 "S": "a1520a4e-1284-4128-bbf5-b52f9c74f039"
#             },
#             "EngagementVersion": {
#                 "S": "1"
#             },
#             "TimeStamp": {
#                 "S": "11/20/2020 14:14:49"
#             }
#         }
#     ],
#     "Count": 5,
#     "ScannedCount": 5,
#     "ConsumedCapacity": null
# }

# %%
$records = aws dynamodb scan --table-name EngagementEventsTable --endpoint-url $ENDPOINT | ConvertFrom-Json

# %%
$records.Items | Select -Property EngagementEventId, EngagementVersion
# Out:
# EngagementEventId                         EngagementVersion
# -----------------                         -----------------
# @{S=4e53920c-505a-4a90-a694-b9300791f0ae} @{S=1}
# @{S=4e53920c-505a-4a90-a694-b9300791f0ae} @{S=2}
# @{S=4e53920c-505a-4a90-a694-b9300791f0ae} @{S=3}
# @{S=fd58911c-8285-467e-aaeb-9f27f76d84c4} @{S=1}
# @{S=a1520a4e-1284-4128-bbf5-b52f9c74f039} @{S=1}

# %%
$records.Items | %{ [PSCustomObject] @{
    EngagementEventId=$_.EngagementEventId.S; 
    EngagementVersion=$_.EngagementVersion.S 
}}
# Out:
# EngagementEventId                    EngagementVersion
# -----------------                    -----------------
# 4e53920c-505a-4a90-a694-b9300791f0ae 1
# 4e53920c-505a-4a90-a694-b9300791f0ae 2
# 4e53920c-505a-4a90-a694-b9300791f0ae 3
# fd58911c-8285-467e-aaeb-9f27f76d84c4 1
# a1520a4e-1284-4128-bbf5-b52f9c74f039 1

# %%
echo aws dynamodb delete-item --table-name EngagementEventsTable --key @'
{
    ""EngagementEventId"":{""S"":""BS.Domain.DAL.EventEnvelopeDal+envelope@75""},
    ""EngagementVersion"":{""S"":""1""}
}
'@
# Out:
# aws
# dynamodb
# delete-item
# --table-name
# EngagementEventsTable
# --key
# {
#     ""EngagementEventId"":{""S"":""BS.Domain.DAL.EventEnvelopeDal+envelope@75""},
#     ""EngagementVersion"":{""S"":""1""}
# }

# %%
echo @'
{"EngagementEventId":{"S":"BS.Domain.DAL.EventEnvelopeDal+envelope@75"},
"EngagementVersion":{"S":"1"}}
'@
# Out:
# {"EngagementEventId":{"S":"BS.Domain.DAL.EventEnvelopeDal+envelope@75"},
# "EngagementVersion":{"S":"1"}}
